# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\DataScience\Python\dataset\Mobile_data.csv")

# %%
df.shape
# Out:
# (2000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   clock_speed    2000 non-null   float64
#  2   fc             2000 non-null   int64
#  3   int_memory     2000 non-null   int64
#  4   m_dep          2000 non-null   float64
#  5   mobile_wt      2000 non-null   int64
#  6   n_cores        2000 non-null   int64
#  7   pc             2000 non-null   int64
#  8   px_height      2000 non-null   int64
#  9   px_width       2000 non-null   int64
#  10  ram            2000 non-null   int64
#  11  sc_h           2000 non-null   int64
#  12  sc_w           2000 non-null   int64
#  13  talk_time      2000 non-null   int64
#  14  price_range    2000 non-null   int64
# dtypes: float64(2), int64(13)
# memory usage: 234.5 KB

# %%
df.columns
# Out:
# Index(['battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep',
#        'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h',
#        'sc_w', 'talk_time', 'price_range'],
#       dtype='object')

# %%
df.head()
# Out:
#    battery_power  clock_speed  fc  int_memory  m_dep  mobile_wt  n_cores  pc  \
# 0            842          2.2   1           7    0.6        188        2   2
# 1           1021          0.5   0          53    0.7        136        3   6
# 2            563          0.5   2          41    0.9        145        5   6
# 3            615          2.5   0          10    0.8        131        6   9
# 4           1821          1.2  13          44    0.6        141        2  14
#
#    px_height  px_width   ram  sc_h  sc_w  talk_time  price_range
# 0         20       756  2549     9     7         19            1
# 1        905      1988  2631    17     3          7            2
# 2       1263      1716  2603    11     2          9            2
# 3       1216      1786  2769    16     8         11            2
# 4       1208      1212  1411     8     2         15            1

# %%
df.tail()
# Out:
#       battery_power  clock_speed  fc  int_memory  m_dep  mobile_wt  n_cores  \
# 1995            794          0.5   0           2    0.8        106        6
# 1996           1965          2.6   0          39    0.2        187        4
# 1997           1911          0.9   1          36    0.7        108        8
# 1998           1512          0.9   4          46    0.1        145        5
# 1999            510          2.0   5          45    0.9        168        6
#
#       pc  px_height  px_width   ram  sc_h  sc_w  talk_time  price_range
# 1995  14       1222      1890   668    13     4         19            0
# 1996   3        915      1965  2032    11    10         16            2
# 1997   3        868      1632  3057     9     1          5            3
# 1998   5        336       670   869    18    10         19            0
# 1999  16        483       754  3919    19     4          2            3

# %%
sns.countplot(df.price_range)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='count'>

# %%
df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# px_width       2000.0  1251.51550   432.199447  500.0   874.75  1247.0
# ram            2000.0  2124.21300  1084.732044  256.0  1207.50  2146.5
# sc_h           2000.0    12.30650     4.213245    5.0     9.00    12.0
# ...

# %%
df.corr()
# Out:
#                battery_power  clock_speed        fc  int_memory     m_dep  \
# battery_power       1.000000     0.011482  0.033334   -0.004004  0.034085
# clock_speed         0.011482     1.000000 -0.000434    0.006545 -0.014364
# fc                  0.033334    -0.000434  1.000000   -0.029133 -0.001791
# int_memory         -0.004004     0.006545 -0.029133    1.000000  0.006886
# m_dep               0.034085    -0.014364 -0.001791    0.006886  1.000000
# mobile_wt           0.001844     0.012350  0.023618   -0.034214  0.021756
# n_cores            -0.029727    -0.005724 -0.013356   -0.028310 -0.003504
# pc                  0.031441    -0.005245  0.644595   -0.033273  0.026282
# px_height           0.014901    -0.014523 -0.009990    0.010441  0.025263
# px_width           -0.008402    -0.009476 -0.005176   -0.008335  0.023566
# ram                -0.000653     0.003443  0.015099    0.032813 -0.009434
# sc_h               -0.029959    -0.029078 -0.011014    0.037771 -0.025348
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see only 4 features are affecting the price_range mostly, i.e ram, px_height, px_width, battery_power

# %%
sns.lineplot(df.price_range,df.ram)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %% [markdown]
# we can see ram is showing linear relatinship with price_range

# %%
sns.boxplot(df.price_range,df.battery_power)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %%
sns.lineplot(df.price_range,df.battery_power)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %% [markdown]
# we can see battery also show almost linear relationship with price_range

# %%
sns.lineplot(df.pc,df.price_range)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pc', ylabel='price_range'>

# %%
sns.lineplot(df.fc,df.price_range)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fc', ylabel='price_range'>

# %%
sns.lineplot(df.fc,df.pc)

# highly correlated to each other
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fc', ylabel='pc'>

# %%
sns.lineplot(df.px_height,df.px_width)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='px_height', ylabel='px_width'>

# %%
sns.lineplot(df.price_range,df.px_height)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='px_height'>

# %%
sns.lineplot(df.price_range,df.px_width)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='px_width'>

# %%
sns.distplot(df.ram)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ram', ylabel='Density'>

# %% [markdown]
# distribution shows the data is free from outliners

# %%
sns.distplot(df.battery_power)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='battery_power', ylabel='Density'>

# %% [markdown]
# outliners free distribution , i.e to extreme values

# %%
sns.distplot(df.px_height)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='px_height', ylabel='Density'>

# %%
sns.distplot(df.px_width)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='px_width', ylabel='Density'>

# %%
# x=df.iloc[:,df.columns!="price_range"]
# y=df.iloc[:,df.columns=="price_range"]

x=df[["battery_power","px_width","ram","px_height"]]
y=df["price_range"]

# %%
x.head()
# Out:
#    battery_power  px_width   ram  px_height
# 0            842       756  2549         20
# 1           1021      1988  2631        905
# 2            563      1716  2603       1263
# 3            615      1786  2769       1216
# 4           1821      1212  1411       1208

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1500, 4)
# (1500,)
# (500, 4)
# (500,)

# %%
# peforming feature scalling using standard scaler

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# # Training a KNN with data and check it’s performance

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn.fit(x_train, y_train)

y_pred_knn = knn.predict(x_test)


#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix 
from sklearn import metrics

cm= confusion_matrix(y_test,y_pred_knn)  
print("Confusion matrix: \n",cm)

from sklearn.metrics import accuracy_score
print('\nAccuracy: ',accuracy_score(y_test, y_pred_knn))
score = knn.score(x_test, y_test)

plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# Confusion matrix:
#  [[118   6   0   0]
#  [  9  97   4   0]
#  [  0  10 103  12]
#  [  0   0  19 122]]
#
# Accuracy:  0.88

# %% [markdown]
# # Getting an optimized number of neighbours

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier


model = KNeighborsClassifier()
n_neighbors = range(1, 21, 2)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']


grid = dict(n_neighbors=n_neighbors,weights=weights,metric=metric)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(x_train, y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.906667 using {'metric': 'manhattan', 'n_neighbors': 19, 'weights': 'distance'}

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 19, metric = 'manhattan', weights="distance", p=2)
knn.fit(x_train, y_train)

y_pred_knn = knn.predict(x_test)


#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix 
from sklearn import metrics

cm= confusion_matrix(y_test,y_pred_knn)  
print("Confusion matrix: \n",cm)

from sklearn.metrics import accuracy_score
print('\nAccuracy: ',accuracy_score(y_test, y_pred_knn))
score = knn.score(x_test, y_test)

plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# Confusion matrix:
#  [[120   4   0   0]
#  [  8  97   5   0]
#  [  0   8 111   6]
#  [  0   0  13 128]]
#
# Accuracy:  0.912
